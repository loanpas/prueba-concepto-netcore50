-- %% [markdown]
-- # [DbPruebaConcepto5.0]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [DbPruebaConcepto5.0]    Script Date: 4/4/2022 4:13:07 p. m. ******/
CREATE DATABASE [DbPruebaConcepto5.0]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'DbPruebaConcepto5.0', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\DbPruebaConcepto5.0.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'DbPruebaConcepto5.0_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\DbPruebaConcepto5.0_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [DbPruebaConcepto5.0] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [DbPruebaConcepto5.0].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [DbPruebaConcepto5.0] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [DbPruebaConcepto5.0] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [DbPruebaConcepto5.0] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [DbPruebaConcepto5.0] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [DbPruebaConcepto5.0] SET ARITHABORT OFF 
GO
ALTER DATABASE [DbPruebaConcepto5.0] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [DbPruebaConcepto5.0] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [DbPruebaConcepto5.0] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [DbPruebaConcepto5.0] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [DbPruebaConcepto5.0] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [DbPruebaConcepto5.0] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [DbPruebaConcepto5.0] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [DbPruebaConcepto5.0] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [DbPruebaConcepto5.0] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [DbPruebaConcepto5.0] SET  DISABLE_BROKER 
GO
ALTER DATABASE [DbPruebaConcepto5.0] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [DbPruebaConcepto5.0] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [DbPruebaConcepto5.0] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [DbPruebaConcepto5.0] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [DbPruebaConcepto5.0] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [DbPruebaConcepto5.0] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [DbPruebaConcepto5.0] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [DbPruebaConcepto5.0] SET RECOVERY FULL 
GO
ALTER DATABASE [DbPruebaConcepto5.0] SET  MULTI_USER 
GO
ALTER DATABASE [DbPruebaConcepto5.0] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [DbPruebaConcepto5.0] SET DB_CHAINING OFF 
GO
ALTER DATABASE [DbPruebaConcepto5.0] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [DbPruebaConcepto5.0] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [DbPruebaConcepto5.0] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [DbPruebaConcepto5.0] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'DbPruebaConcepto5.0', N'ON'
GO
ALTER DATABASE [DbPruebaConcepto5.0] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[Espacios]

-- %%
USE [DbPruebaConcepto5.0]
GO

-- %%
/****** Object:  Table [dbo].[Espacios]    Script Date: 4/4/2022 4:13:08 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Espacios](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[nombre] [nvarchar](50) NULL,
	[direccion] [nvarchar](100) NOT NULL,
	[descripcion] [nvarchar](max) NULL,
	[latitud] [nvarchar](50) NOT NULL,
	[longitud] [nvarchar](50) NOT NULL,
 CONSTRAINT [PK_Espacios] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [DbPruebaConcepto5.0]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [DbPruebaConcepto5.0] SET  READ_WRITE 
GO
